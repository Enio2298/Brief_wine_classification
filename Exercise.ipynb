# %%
import pandas as pd

# %%
df = pd.read_csv("wines.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'name', 'points', 'price',
#        'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
df = df[["country","name","points","price"]]

# %%
print(df)
# Out:
#          country                                    name  points  price
# 0          Italy                            Vulkà Bianco      87    NaN
# 1       Portugal                                Avidagos      87   15.0
# 2             US                                     NaN      87   14.0
# 3             US                    Reserve Late Harvest      87   13.0
# 4             US      Vintner's Reserve Wild Child Block      87   65.0
# ...          ...                                     ...     ...    ...
# 129966   Germany  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
# 129967        US                                     NaN      90   75.0
# 129968    France                                   Kritt      90   30.0
# 129969    France                                     NaN      90   32.0
# 129970    France           Lieu-dit Harth Cuvée Caroline      90   21.0
#
# [129971 rows x 4 columns]

# %%
df["price"] = df["price"].mask(df["price"] == 0)

# %%
df["Stars"] = df["points"]*0.05
df
# Out:
#           country           name  points  price  Stars
# 117303      Spain    Flirty Bird      82    4.0   4.10
# 59507          US        Unoaked      83    4.0   4.15
# 29553   Argentina            Red      84    4.0   4.20
# 31530          US            NaN      84    4.0   4.20
# 61768       Spain            NaN      84    4.0   4.20
# ...           ...            ...     ...    ...    ...
# 111757     France            NaN      99    NaN   4.95
# 111758     France            NaN      99    NaN   4.95
# 116093     France  Barrel sample      99    NaN   4.95
# 116094     France  Barrel sample      99    NaN   4.95
# 116095     France  Barrel sample      99    NaN   4.95
#
# [129971 rows x 5 columns]

# %%
len(df.loc[df["Stars"] == 5])
# Out:
# 19

# %%
caro = df.loc[df["price"] == df["price"].max()]

# %%
print(caro)
# Out:
#       country                name  points   price  Stars
# 80290  France  Glamorosa Sensible      88  3300.0    4.4

# %%
df.loc[df["price"] < 100]["price"].hist()
# Out:
# <Axes: >

# %%
df = df.sort_values(by=["price", "Stars"], axis=0)

# %%
df.plot(x="price",y="Stars", figsize=(30,6), kind="scatter")
# Out:
# <Axes: xlabel='price', ylabel='Stars'>
